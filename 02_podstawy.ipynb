# %% [markdown]
# <a href="https://colab.research.google.com/github/liskatarzyna/Colab/blob/main/02_podstawy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-


# %%
imie = input('Podaj swoje imie: ')

# print('Czesc', imie)
print('Czesc {}!'.format(imie))

# %%
jezyk = input('Jakiego języka chcesz się nauczyć? ')

print('Podano język {}'.format(jezyk))

# %%
name = input('Podaj imie: ')
age = input('Podaj wiek: ')

print('Czesc {}! Masz {} lat.'.format(name, age))

# %%
age = int(input('Podaj wiek: '))
# Out:
# Podaj wiek: 39
