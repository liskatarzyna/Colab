# %% [markdown]
# <a href="https://colab.research.google.com/github/liskatarzyna/Colab/blob/main/04_podstawy_wycinanie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-


name = 'Python'

# %%
# print(name[0])
print(name[-2])
print(name[::-1])

# %%
# name[start:stop]
# name[:stop]
# name[start:]
# name[start:stop:step]
name[1:4]
name[:4]
name[2:]

name[:]

name[0]

# %%
name[-3:]
name[-3:-1]

# %%
full = 'Python Programming'
print(full[7:])
print(full[::2])

test = '0123456789'
print(test[::2])
print(test[3:7:2])
print(test[4:6])
print(test[::-2])


# %%
sample = '#stop#this#flow'
print(sample[::5])

# %%
numbers = '8,9,7,4'
print(numbers[::2])

# %%
print(numbers[::-1])

# %%
name = 'kajak'
print(name[::-2])
# %%

name = 'Python'

'Py' in name
'java' in name
# Out:
# 97531
