# %% [markdown]
# <a href="https://colab.research.google.com/github/liskatarzyna/Colab/blob/main/06_podstawy_string_metody.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-


text = 'Witaj na kursie Pythona.\nPython jest wspaniały.'

print(text)

# %%
dir(text)
help(str.count)

# %%


text = 'test test test .\n test test test.'


text.capitalize()
help(str.capitalize)


# %%

text = 'test test test.\n test test test.'

text.title()
help(str.title)


# %%
text.count('Python')
# Out:
# 'Test test test .\n test test test.'

# %%
# %%
text.startswith('kurs')

# %%
'python'.startswith('py')

# %%
text.endswith('y.')

# %%
'sample.txt'.endswith('.py')


# %%
'sample.png'.endswith('.png')

# %%
text = 'Witaj na kursie Pythona.\nPython jest wspaniały.'
text.find('Python')
text[text.find('Python'):]

# %%
hashtags = 'sport#gym'
idx = hashtags.find('#')
hashtags[:idx]

# %%
'pawel545'.isalnum()
help(str.isalnum)

# %%
'43434fvd'.isdigit()
help(str.isdigit)

# %%
'pyThon'.islower()

'PAWEL'.isupper()

# %%
' '.join(['python', '3.7'])
'#'.join(['sport', 'gym', 'fit'])
','.join(['1', '2', '3', '4'])
# Out:
# '1,2,3,4'

# %%
# %%
'#good#time#mood'.replace('#', ' ')

# %%
'column name'.replace(' ', '_')

# %%
'    python   '.strip()
'    python   '.rstrip()
'    python   '.lstrip()

# %%
'1,2,3,4,5'.split(',')

'python java php sql sas'.split()

'#gym#fit#mood'.split('#')

# %%
'12'.zfill(5)
'1'.zfill(10)
# Out:
# ' good time mood'
