# %% [markdown]
# <a href="https://colab.research.google.com/github/liskatarzyna/Colab/blob/main/21_przeplyw_programu_while_przyklady.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-


KOD_PIN = '0000'

pin = input('Podaj kod pin: ')

while pin != KOD_PIN:
    pin = input('Sproboj ponownie jeszcze raz: ')

print('Zalogowany!')

# %%
KOD_PIN = '0000'

pin = ''
counter = 0

while pin != KOD_PIN and counter < 3:
    pin = input('Wprowadz kod pin: ')
    if pin == KOD_PIN:
        print('Zalogowany')
        break
    counter += 1
else:
    print('Zbyt dużo prób logowania.')
