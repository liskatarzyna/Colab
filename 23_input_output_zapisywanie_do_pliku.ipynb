# %% [markdown]
# <a href="https://colab.research.google.com/github/liskatarzyna/Colab/blob/python_podstawy/23_input_output_zapisywanie_do_pliku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-


import os

user = os.environ.get('USER')
print(user)

path = os.environ['PATH']
print(path)


desktop = os.path.join(os.path.join(os.environ['liska']), 'Pulpit')
print(desktop)



from google.colab import files

# Zapisz plik najpierw w środowisku Colab
with open('przyklad.txt', 'w') as f:
  f.write('Zawartość pliku')

# Pobierz plik na komputer
files.download('przyklad.txt')


techs = ['python', 'java', 'sql', 'r', 'scala']

with open('techs.txt', 'w') as file:
    for tech in techs:
        print(tech, file=file)

# %%
even_number = list(range(100))[::2]

with open('numbers.txt', 'w') as file:
    for number in even_number:
        file.write(str(number) + '\n')

# %%
techs = ['python', 'java', 'sql', 'r', 'scala']

with open('techs.txt', 'a') as file:
    for tech in techs:
        print(tech, file=file)

# %%
technologies = []
with open('techs.txt', 'r') as file:
    for line in file:
        technologies.append(line)
print(technologies)

# %%
technologies = []
with open('techs.txt', 'r') as file:
    for line in file:
        technologies.append(line[:-1])
print(technologies)

# %%
with open('tree_2.txt', 'w') as file:
    for j in range(2):
        for i in range(10):
            print('{:>9}'.format('*' * i), end='', file=file)
            print('{}'.format('*' * i), file=file)
