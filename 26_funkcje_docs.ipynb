# %% [markdown]
# <a href="https://colab.research.google.com/github/liskatarzyna/Colab/blob/main/26_funkcje_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-


def add(a, b):
    """Zwraca sumę dwóch liczb.

    Inputs:
        a: int
        b: int

    Outputs:
        sum: int"""
    return a + b

# %%
help(add)
